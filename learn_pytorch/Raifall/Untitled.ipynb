# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train.csv')
print(train.shape)
train.head()
# Out:
# (2190, 13)
#    id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0   0    1    1017.4     21.2         20.6     19.9      19.4      87.0
# 1   1    2    1019.5     16.2         16.9     15.8      15.4      95.0
# 2   2    3    1024.1     19.4         16.1     14.6       9.3      75.0
# 3   3    4    1013.4     18.1         17.8     16.9      16.8      95.0
# 4   4    5    1021.8     21.3         18.4     15.2       9.6      52.0
#
#    cloud  sunshine  winddirection  windspeed  rainfall
# 0   88.0       1.1           60.0       17.2         1
# 1   91.0       0.0           50.0       21.9         1
# 2   47.0       8.3           70.0       18.1         1
# 3   95.0       0.0           60.0       35.6         1
# 4   45.0       3.6           40.0       24.8         0

# %%
test = pd.read_csv('data/test.csv')
print(test.shape)
test.head()
# Out:
# (730, 12)
#      id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0  2190    1    1019.5     17.5         15.8     12.7      14.9      96.0
# 1  2191    2    1016.5     17.5         16.5     15.8      15.1      97.0
# 2  2192    3    1023.9     11.2         10.4      9.4       8.9      86.0
# 3  2193    4    1022.9     20.6         17.3     15.2       9.5      75.0
# 4  2194    5    1022.2     16.1         13.8      6.4       4.3      68.0
#
#    cloud  sunshine  winddirection  windspeed
# 0   99.0       0.0           50.0       24.3
# 1   99.0       0.0           50.0       35.3
# 2   96.0       0.0           40.0       16.9
# 3   45.0       7.1           20.0       50.6
# 4   49.0       9.2           20.0       19.4

# %%
RMV_TRAIN = ['rainfall', 'id']
RMV_TEST = ['id']
FEATURES = [col for col in train.columns if col not in RMV_TRAIN]
TRAGET = 'rainfall'
TEST = [col for col in test.columns if col not in RMV_TEST]
print(FEATURES)
# Out:
# ['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity', 'cloud', 'sunshine', 'winddirection', 'windspeed']

# %%
train.drop_duplicates(inplace=True)
train.isnull().sum()
# Out:
# id               0
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    0
# windspeed        0
# rainfall         0
# dtype: int64

# %%
train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import AUC

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(train[FEATURES])
X_test_scaled = scaler.transform(test[TEST])
X_train, X_val, y_train, y_val = train_test_split(X_scaled, train[TRAGET], test_size=0.2, random_state=42)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_scaled = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, MaxPool1D, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    Conv1D(filters=32, kernel_size=3, activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
from tensorflow.keras.optimizers import SGD
optimizer = SGD(
    learning_rate=0.001,
    momentum=0.9,
    decay=1e-6,
)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[AUC(name='auc')])
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-6, verbose=1)
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 1s 4ms/step - loss: 0.6710 - auc: 0.4750 - val_loss: 0.6509 - val_auc: 0.5321 - lr: 0.0010
# Epoch 2/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6208 - auc: 0.5545 - val_loss: 0.6102 - val_auc: 0.7252 - lr: 0.0010
# Epoch 3/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5793 - auc: 0.6568 - val_loss: 0.5779 - val_auc: 0.8121 - lr: 0.0010
# Epoch 4/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5459 - auc: 0.7722 - val_loss: 0.5535 - val_auc: 0.8314 - lr: 0.0010
# Epoch 5/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5190 - auc: 0.8384 - val_loss: 0.5325 - val_auc: 0.8405 - lr: 0.0010
# Epoch 6/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.4948 - auc: 0.8541 - val_loss: 0.5111 - val_auc: 0.8457 - lr: 0.0010
# Epoch 7/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.4693 - auc: 0.8653 - val_loss: 0.4886 - val_auc: 0.8502 - lr: 0.0010
# Epoch 8/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.4477 - auc: 0.8677 - val_loss: 0.4672 - val_auc: 0.8530 - lr: 0.0010
# Epoch 9/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.4210 - auc: 0.8776 - val_loss: 0.4449 - val_auc: 0.8553 - lr: 0.0010
# Epoch 10/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.4007 - auc: 0.8751 - val_loss: 0.4263 - val_auc: 0.8578 - lr: 0.0010
# Epoch 11/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3789 - auc: 0.8806 - val_loss: 0.4112 - val_auc: 0.8569 - lr: 0.0010
# Epoch 12/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3623 - auc: 0.8879 - val_loss: 0.4017 - val_auc: 0.8573 - lr: 0.0010
# Epoch 13/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3496 - auc: 0.8893 - val_loss: 0.3968 - val_auc: 0.8592 - lr: 0.0010
# Epoch 14/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3436 - auc: 0.8867 - val_loss: 0.3951 - val_auc: 0.8599 - lr: 0.0010
# Epoch 15/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3403 - auc: 0.8881 - val_loss: 0.3948 - val_auc: 0.8609 - lr: 0.0010
# Epoch 16/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3425 - auc: 0.8841 - val_loss: 0.3947 - val_auc: 0.8624 - lr: 0.0010
# Epoch 17/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3319 - auc: 0.8928 - val_loss: 0.3971 - val_auc: 0.8609 - lr: 0.0010
# Epoch 18/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3388 - auc: 0.8878 - val_loss: 0.3966 - val_auc: 0.8623 - lr: 0.0010
# Epoch 19/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3373 - auc: 0.8856 - val_loss: 0.3965 - val_auc: 0.8614 - lr: 0.0010
# Epoch 20/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3265 - auc: 0.8947 - val_loss: 0.3962 - val_auc: 0.8622 - lr: 0.0010
# Epoch 21/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3335 - auc: 0.8928 - val_loss: 0.3964 - val_auc: 0.8629 - lr: 0.0010
# Epoch 22/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3316 - auc: 0.8895 - val_loss: 0.3972 - val_auc: 0.8629 - lr: 0.0010
# Epoch 23/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3326 - auc: 0.8887 - val_loss: 0.3971 - val_auc: 0.8619 - lr: 0.0010
# Epoch 24/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3293 - auc: 0.8930 - val_loss: 0.3980 - val_auc: 0.8615 - lr: 0.0010
# Epoch 25/100
# 36/55 [==================>...........] - ETA: 0s - loss: 0.3265 - auc: 0.8905
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3353 - auc: 0.8871 - val_loss: 0.3975 - val_auc: 0.8615 - lr: 0.0010
# Epoch 26/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3263 - auc: 0.8937 - val_loss: 0.3975 - val_auc: 0.8617 - lr: 1.0000e-04
# Epoch 27/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3298 - auc: 0.8916 - val_loss: 0.3974 - val_auc: 0.8616 - lr: 1.0000e-04
# Epoch 28/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3261 - auc: 0.8961 - val_loss: 0.3975 - val_auc: 0.8618 - lr: 1.0000e-04
# Epoch 29/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3269 - auc: 0.8945 - val_loss: 0.3975 - val_auc: 0.8617 - lr: 1.0000e-04
# Epoch 30/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3335 - auc: 0.8862 - val_loss: 0.3975 - val_auc: 0.8618 - lr: 1.0000e-04
# Epoch 31/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3365 - auc: 0.8860 - val_loss: 0.3976 - val_auc: 0.8619 - lr: 1.0000e-04
# Epoch 32/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3312 - auc: 0.8916 - val_loss: 0.3976 - val_auc: 0.8621 - lr: 1.0000e-04
# Epoch 33/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3354 - auc: 0.8888 - val_loss: 0.3973 - val_auc: 0.8615 - lr: 1.0000e-04
# Epoch 34/100
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3285 - auc: 0.8968 - val_loss: 0.3975 - val_auc: 0.8621 - lr: 1.0000e-04
# Epoch 35/100
# 33/55 [=================>............] - ETA: 0s - loss: 0.3375 - auc: 0.8904
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 55/55 [==============================] - 0s 2ms/step - loss: 0.3303 - auc: 0.8902 - val_loss: 0.3974 - val_auc: 0.8618 - lr: 1.0000e-04
# Epoch 36/100
# 51/55 [==========================>...] - ETA: 0s - loss: 0.3373 - auc: 0.8845Restoring model weights from the end of the best epoch: 16.
# 55/55 [==============================] - 0s 3ms/step - loss: 0.3337 - auc: 0.8871 - val_loss: 0.3975 - val_auc: 0.8620 - lr: 1.0000e-05
# Epoch 36: early stopping

# %%
test_preds = model.predict(X_test_scaled).flatten()
if np.isnan(test_preds).sum() > 0:
    print(f"Found {np.isnan(test_preds).sum()} NaN values in predictions. Fixing them...")
    test_preds = np.nan_to_num(test_preds)
submission = pd.DataFrame({'id': test['id'], 'rainfall': test_preds})
submission.to_csv('data/submission.csv', index=False)
# Out:
# 23/23 [==============================] - 0s 691us/step

# %%
submission.head()
# Out:
#      id  rainfall
# 0  2190  0.977889
# 1  2191  0.978699
# 2  2192  0.946014
# 3  2193  0.163925
# 4  2194  0.086036
